# %%
import matplotlib.pyplot as plt
import pandas as pd
import japanize_matplotlib

# csvファイルをデータフレームとして読み込む
df = pd.read_csv("sample_data/sample_pandas_6.csv")
df = pd.merge(df, category_df[['商品番号', 'カテゴリー']], how='inner', on='商品番号')
df['カテゴリー'].value_counts()
df.plot(kind='bar')
plt.show()
df.groupby('商品番号')['発注日'].max()
df.groupby('商品番号')['発注日'].describe()
# Out:
#          count unique         top freq
# 商品番号
# 1QJFO8QY    32     31  2023-03-12    2
# 2HSTCDWM    20     20  2019-08-13    1
# 48XMJXKO    10     10  2018-11-08    1
# 8T7D5DQA    21     21  2015-03-09    1
# MESUDVWQ    17     17  2016-01-06    1
# QRMOGNUU    27     27  2017-01-09    1
# S6RE8W6X    20     20  2022-01-07    1
# X0ZE2ZMY    14     14  2015-07-21    1
# YY4HAAZR    17     17  2016-03-06    1
# Z4WOOIYV    22     22  2015-03-27    1
